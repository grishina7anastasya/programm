# %% [markdown]
# <a href="https://colab.research.google.com/github/grishina7anastasya/programm/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Задание task_01_07.
# Выполнилa: Гришина А.А.
# Группа: ЦИБ-251


team = input('Введите название команды:')

print(team, "- чемпион!")

print("-" * len(team))

# Название команды в нижнем регистре
team_lowercase = team.lower()
print("Символов в названии команды:", len(team))
print('Буква "п" есть:', "п" in team_lowercase)
print('Количество букв "а":', team_lowercase.count("а"))


# --------------
# Пример вывода:
#
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
# Out:
# Введите название команды:Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
